# %%
import glob
import os
import h5py
import pandas as pd
import numpy as np

from src import io, moco, roi, ttl, zdF

# %%
# set main data path
base_data_path = "/Volumes/AhmedLab/princess/data/"

# loop over all directories within princess/data
for folder_name in os.listdir(base_data_path):
    if os.path.isdir(folder_name):
        if "processed" in os.listdir(os.path.join(base_data_path,folder_name):
    # if folder_name == ".DS_Store" or "processed" in os.listdir(os.path.join(base_data_path, folder_name)):
            continue
        else:
            print(folder_name)
# Out:
# 250710
# 250730_901
# 250814_201
# 250821_1101
# 250829_1201
# 250917_1401
# 250918_1501
# 250923_1601
# 251014_1801
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[2], line 6
#       4 # loop over all directories within princess/data
#       5 for folder_name in os.listdir(base_data_path):
# ----> 6     if folder_name == ".DS_Store" or "processed" in os.listdir(os.path.join(base_data_path, folder_name)):
#       7         continue
#       8     else:
#
# NotADirectoryError: [Errno 20] Not a directory: '/Volumes/AhmedLab/princess/data/AVG_TSeries-07302025-901_channel_1.tif'
